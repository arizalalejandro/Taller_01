# %% [markdown]
# <a href="https://colab.research.google.com/github/arizalalejandro/Taller_01/blob/main/Alejo_Taller_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Taller en clase #1
# Generando numeros aleatorios en ptython. Objetivos:
#
# Familiarizar al estudiante con la generación de numeros aleatorios de diferentes distribuciones en python.
# Usar las herramientas de python de manejo de arreglos.
# Usar las herramientas de generación de gráficas de python.
# Entrega
# En U-virtual, antes de la siguiente clase en el link designado como Taller en clase 1.

# %%
import numpy  #as np# si no lo tiene instalado por favor correr en su consola         $pip install numpy
import scipy #as sp# si no lo tiene instalado por favor correr en su consola         $pip install scipy
import matplotlib #si no lo tiene instalado por favor correr  en su consola   $pip install matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ## Primer punto Distribuciones discretas.
# 1. Cree un arreglo de N muestras con N a su selección, pero mayor a 1000, de números distribuidos con las correspondientes distribuciones, para cada arreglo de números:
# 1. Grafique los números aleatorios,
# 2. Ordene de menor a mayor y grafique,
# 4. Encuentre los valores teoricos de media y varianza, y comparelos con los estimados.

# %%
#Para todas las simulaciones:
N=100000
m=3000
numpy.random.seed(seed=2**32 - 1)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# bernoulli con cierto p entre 0 y 1
p=0.3
from scipy.stats import bernoulli
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk')
r = bernoulli.rvs(p, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.3 son u= 0.3 var= 0.21
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p= 0.3 son u_est= 0.29788 var_est= 0.20914750560000003

# %%
# binomial con cierto p entre 0 y 1 y cierto n
from scipy.stats import binom
import matplotlib.pyplot as plt
n,p = 10, 0.5
mean, var, skew, kurt = binom.stats(n, p, moments='mvsk')
r = binom.rvs(n, p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomialmente con n="+str(n) + " y p=" +str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomial ordenados con n="+str(n) + " y p=" +str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial con p="+str(p) + "y n=" +str(n))
plt.show()
print("Tipo del arreglo r:" + str(type(r)))
print("Estimaciones de estadisticas de r:")
avg=r.mean()
varest=r.var()
print("-Valores teóricos para la binomial con p=",p, 'y n=',n, "son: u=" ,mean,"var=",var)
print("-Los valores estimados en nuestro experimento para la binomial con p=",p, 'y n=',p)
print( " son: u_est=" ,avg,"var_est=",varest)
# Out:
# Tipo del arreglo r:<class 'numpy.ndarray'>
# Estimaciones de estadisticas de r:
# -Valores teóricos para la binomial con p= 0.5 y n= 10 son: u= 5.0 var= 2.5
# -Los valores estimados en nuestro experimento para la binomial con p= 0.5 y n= 0.5
#  son: u_est= 4.99334 var_est= 2.5004556443999997

# %%
# Geométrica con cierto p entre 0 y 1
from scipy.stats import geom
import matplotlib.pyplot as plt
p = 0.3
mean, var, skew, kurt = geom.stats(p, moments='mvsk')
r = geom.rvs(p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos geometricamente con p="+str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos geometricamente ordenados con p="+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos geometricamente con p="+str(p))
plt.show()
print('Tipo del arreglo r:', type(r))
print("Estimaciones de estadisticas de r:") 
avg=r.mean()
varest=r.var()
print("-Valores teóricos para la geométrica con p=",p,"son: u=" ,mean,"var=",var)
print("-Los valores estimados en nuestro experimento para la geométrica con p=",p)
print("son: u_est=" ,avg,"var_est=",varest)
# Out:
# Tipo del arreglo r: <class 'numpy.ndarray'>
# Estimaciones de estadisticas de r:
# -Valores teóricos para la geométrica con p= 0.3 son: u= 3.3333333333333335 var= 7.777777777777779
# -Los valores estimados en nuestro experimento para la geométrica con p= 0.3
# son: u_est= 3.31584 var_est= 7.697925094400001

# %%
# Poisson con cierto Lamnda L
from scipy.stats import poisson
import matplotlib.pyplot as plt
L = 5
mean, var, skew, kurt = poisson.stats(L, moments='mvsk')
r = poisson.rvs(L, size=1000)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos poisson con L="+str(L))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos poisson ordenados con L="+str(L))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos poisson con L="+str(L))
plt.show()
print('Tipo del arreglo r:',type(r))
print("Estimaciones de estadisticas de r:")
avg=r.mean()
varest=r.var()
print("-Valores teoricos para la Poisson con L=",L,"son: u=" ,mean,"- var=",var)
print("-Los valores estimados en nuestro experimento para la Poisson con L=",L)
print(" son: u_est=" ,avg,"- var_est=",varest)
# Out:
# Tipo del arreglo r: <class 'numpy.ndarray'>
# Estimaciones de estadisticas de r:
# -Valores teoricos para la Poisson con L= 5 son: u= 5.0 - var= 5.0
# -Los valores estimados en nuestro experimento para la Poisson con L= 5
#  son: u_est= 4.928 - var_est= 4.728816

# %%
#Binomial negativa con parametro p después de r fallos
from scipy.stats import nbinom
import matplotlib.pyplot as plt
r_,p = 5, 0.5
mean, var, skew, kurt = nbinom.stats(n, p, moments='mvsk')
r = nbinom.rvs(n, p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomial negativa con r="+str(r_) + " y p=" +str(p))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomial negativa ordenados con r="+str(r_)+ 'y p='+str(p))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial negativa con p="+str(p))
plt.show()
print('Tipo del arreglo r:', type(r))
print("Estimaciones de estadisticas de r:")
avg=r.mean()
varest=r.var()
print("-Valores teoricos para la binomial negativa con r=",r_, 'y con p=',p ,"son: u=" ,mean,"- var=",var)
print("-Valores estimados en nuestro experimento para la binomial con r=",r_, "y con p=",p)
print(" son: u_est=" ,avg,"- var_est=",varest)
# Out:
# Tipo del arreglo r: <class 'numpy.ndarray'>
# Estimaciones de estadisticas de r:
# -Valores teoricos para la binomial negativa con r= 5 y con p= 0.5 son: u= 10.0 - var= 20.0
# -Valores estimados en nuestro experimento para la binomial con r= 5 y con p= 0.5
#  son: u_est= 9.98357 - var_est= 20.1316600551

# %% [markdown]
# ## Segundo punto Distribuciones contínuas.

# %%
#Para todas las simulaciones:
N=1000
m=300
numpy.random.seed(seed=1314926535)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# Normal de media 5 y desviación estandar 0.5
u=5
std=0.5
mean, var, skew, kurt = scipy.stats.norm.stats(moments='mvsk',loc=u,scale=std)
r = scipy.stats.norm.rvs (loc=u,scale=std, size=N)
#ver https://docs.scipy.org/doc/scipy-0.14.0/reference/stats.html
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales ordenados con media="+str(u)+" y std="+str(std))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales con u="+str(u)+ " y std= "+str(std))
plt.show()
print("Note que hasta ahora no sabemos el tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
# ver https://numpy.org/doc/stable/reference/routines.statistics.html 
avg=r.mean()
varest=r.var()
print("Valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# Note que hasta ahora no sabemos el tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Valores teoricos de la media y varianza para la normal son u= 5.0 var= 0.25
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 4.971391002002103 var_est= 0.2653971302092896

# %%
# Uniforme entre 0 y 255
u=0
std=255
mean, var, skew, kurt = scipy.stats.uniform.stats(moments='mvsk',loc=u,scale=std)
r = scipy.stats.uniform.rvs (loc=u,scale=std, size=N)
#r = scipy.stats.uniform.rvs(size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos uniforme entre "+str(u)+" y "+str(std))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos uniforme ordenados entre "+str(u)+" y "+str(std))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos uniforme entre "+str(u)+" y "+str(std))
plt.show()
print('Tipo del arreglo r:', type(r))
print("Estimaciones de estadisticas de r:")
avg=r.mean()
varest=r.var()
print("-Valores teoricos para la uniforme son: u=" ,mean,"var=",var)
print("-Valores estimados en nuestro experimento son: u_est=" ,avg,"var_est=",varest)
# Out:
# Tipo del arreglo r: <class 'numpy.ndarray'>
# Estimaciones de estadisticas de r:
# -Valores teoricos para la uniforme son: u= 127.5 var= 5418.75
# -Valores estimados en nuestro experimento son: u_est= 131.82023964436755 var_est= 5434.444821414549

# %%
# Exponencial con Lamnda L
from scipy.stats import expon
import matplotlib.pyplot as plt
L=0.3
mean, var, skew, kurt = expon.stats(L, moments='mvsk')
r = expon.rvs(L, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos exponencial con L=" + str(L))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos exponencial ordenados con L="+str(L))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos exponencial con L="+str(L))
plt.show()
print('Tipo del arreglo r:', type(r))
print("Estimaciones de estadisticas de r:") 
avg=r.mean()
varest=r.var()
print("-Valores teoricos para la exponencial son: u=" ,mean,"var=",var)
print("-Valores estimados en nuestro experimento son: u_est=" ,avg,"var_est=",varest)
# Out:
# Tipo del arreglo r: <class 'numpy.ndarray'>
# Estimaciones de estadisticas de r:
# -Valores teoricos para la exponencial son: u= 1.3 var= 1.0
# -Valores estimados en nuestro experimento son: u_est= 1.3371907692393672 var_est= 1.056747676712383

# %%
#Chi cuadrada con K grados de libertad
from scipy.stats import chi2
import matplotlib.pyplot as plt
K=3.0
mean, var, skew, kurt = chi2.stats(K, moments='mvsk')
r = chi2.rvs(K, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Chi cuadrada con K=" + str(K))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos chi cuadrado ordenados con K="+str(K))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos chi cuadrado ordenados con K="+str(K))
plt.show()
print('Tipo del arreglo r:', type(r))
print("Estimaciones de estadisticas de r:") 
avg=r.mean()
varest=r.var()
print("-Valores teoricos para la chi cuadrado son: u=" ,mean,"var=",var)
print("-Valores estimados en nuestro experimento son: u_est=" ,avg,"var_est=",varest)
# Out:
# Tipo del arreglo r: <class 'numpy.ndarray'>
# Estimaciones de estadisticas de r:
# -Valores teoricos para la chi cuadrado son: u= 3.0 var= 6.0
# -Valores estimados en nuestro experimento son: u_est= 2.9847159165865933 var_est= 5.820181557315513

# %%
#Gamma con parametros k y theta t
from scipy.stats import gamma
import matplotlib.pyplot as plt
k,t=2.54,0.43
mean, var, skew, kurt = gamma.stats(k, t, moments='mvsk')
r = gamma.rvs(k, t,size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos gamma con K=" + str(k) + ' y  t=' + str(t))
plt.show()

# %%
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos gamma ordenados con K=" + str(k) + ' y  t=' + str(t))
plt.show()

# %%
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos gamma con K= "+str(k)+" y t="+str(t))
plt.show()
print('Tipo del arreglo r:', type(r))
print("Estimaciones de estadisticas de r:")
avg=r.mean()
varest=r.var()
print("-Valores teoricos para la gamma son: u=" ,mean,"var=",var)
print("-Valores estimados en nuestro experimento son: u_est=" ,avg,"var_est=",varest)
# Out:
# Tipo del arreglo r: <class 'numpy.ndarray'>
# Estimaciones de estadisticas de r:
# -Valores teoricos para la gamma son: u= 2.97 var= 2.54
# -Valores estimados en nuestro experimento son: u_est= 2.8577950123579976 var_est= 2.1220674376552413
